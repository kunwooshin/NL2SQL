# %%
import pandas as pd

df1 = pd.read_csv('spider_1_1600.csv')
df2 = pd.read_csv('spider_1601_3200.csv')
df3 = pd.read_csv('spider_3201_4800.csv')
df4 = pd.read_csv('spider_4801_6400.csv')
df5 = pd.read_csv('spider_6401_8034.csv')

# %%
result = pd.concat([df1, df2, df3, df4, df5])

# %%
result = result.sort_values('Unnamed: 0')

# %%
result = result.reset_index().drop('index', axis=1)

# %%
result
# Out:
#      Unnamed: 0                  db_id  \
# 0            11  department_management
# 1            13  department_management
# 2            14  department_management
# 3            36                   farm
# 4            37                   farm
# ..          ...                    ...
# 245        7937            dog_kennels
# 246        7940            dog_kennels
# 247        7941            dog_kennels
# 248        7954            dog_kennels
# 249        7955            dog_kennels
#
#                                                  query  \
# 0    SELECT count(*) FROM department WHERE departme...
# 1    SELECT T3.born_state FROM department AS T1 JOI...
# 2    SELECT T1.department_id ,  T1.name ,  count(*)...
# 3    SELECT T1.Official_Name FROM city AS T1 JOIN f...
# 4    SELECT T1.Official_Name FROM city AS T1 JOIN f...
# ..                                                 ...
# 245  SELECT T1.owner_id ,  T1.last_name FROM Owners...
# ...

# %%
result.to_csv('spider_250.csv')

# %%
len(result['Unnamed: 0'].unique())
# Out:
# 250

# %%
duplicates = result.duplicated(keep=False)
duplicate_rows = result[duplicates]
occurrence_count = duplicate_rows.groupby(duplicate_rows.columns.tolist()).size().reset_index(name='counts')
more_than_twice = occurrence_count[occurrence_count['counts'] > 1]

# %%
more_than_twice
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, db_id, query, question, query_toks, query_toks_no_value, question_toks, HAVING, ORDER BY, GROUP BY, JOIN, SELECT, counts]
# Index: []
